# %%
print(__doc__)

# Tryna show a logistic regression graph for the load digits
# Not really sure what it is supposed to do
# Saw an example and I tried to replicate it

from time import time
import numpy as np
import matplotlib.pyplot as plt

from sklearn.linear_model import LogisticRegression
from sklearn.datasets import load_digits
from sklearn.svm import l1_min_c

digits = load_digits()
X = digits.data
y = digits.target

X = X[y != 2]
y = y[y != 2]

X /= X.max() # Normalize X to speed-up convergence

# Demo path functions

cs = l1_min_c(X, y, loss='log') * np.logspace(0, 7, 16)

print("Computing regularization path ...")
start = time()
clf = LogisticRegression(penalty='l1', solver='liblinear',
                      tol= 1e-6, max_iter=int(1e6),
                      warm_start=True,
                      intercept_scaling=10000.)

coefs_ = []
for c in cs:
    clf.set_params(C=c)
    clf.fit(X, y)
    coefs_.append(clf.coef_.ravel().copy())
print("This took %0.3fs" % (time() - start))    

coefs_ = np.array(coefs_)
plt.plot(np.log10(cs), coefs_, marker='o')
ymin, ymax = plt.ylim()
plt.xlabel('log(C)')
plt.ylabel('Coefficients')
plt.title('Logistic Regression Path')
plt.axis('tight')
plt.show()
# Out:
# Automatically created module for IPython interactive environment
# Computing regularization path ...
# This took 35.740s

# %%
print(__doc__)

from sklearn.datasets import load_digits
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB, Cate
X, y = load_digits(return_X_y=True)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
y_pred = gnb.fit(X_train, y_train).predict(X_test)
print("Number of mislabeled points out of a total %d points : %d"
      % (X_test.shape[0], (y_test != y_pred).sum()))
# Out:
# Automatically created module for IPython interactive environment
# Number of mislabeled points out of a total 899 points : 149
